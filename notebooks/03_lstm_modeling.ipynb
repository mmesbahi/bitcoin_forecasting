# %% [markdown]
# ## The LSTM Challenge: Can a "Smarter" Model Find Patterns?
# Now, we move to the 'AI-side'. An LSTM (Long Short-Term Memory) network is a type of deep learning model.
# Its big advantage is that it can look at a "window" of past data (for example the last 30 days) to see if it can learn complex patterns that our simple ARIMA model missed.
#
# If the LSTM can't beat the 4.9% error of our simple flat line, it's not a useful model for this problem!

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

from sklearn.preprocessing import MinMaxScaler # For scaling data
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Set up plotting style
plt.style.use('fivethirtyeight')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 10
#       7 from sklearn.preprocessing import MinMaxScaler # For scaling data
#       8 from sklearn.metrics import mean_squared_error
# ---> 10 from tensorflow.keras.models import Sequential
#      11 from tensorflow.keras.layers import LSTM, Dense, Dropout
#      13 # Set up plotting style
#
# ModuleNotFoundError: No module named 'tensorflow'
